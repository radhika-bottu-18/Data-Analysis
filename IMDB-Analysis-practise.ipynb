# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\DataScienceAndAICourse\\PYTHON-VSCODE\\Seaborn'

# %%
movies= pd.read_csv(r'C:\DataScienceAndAICourse\february\27-seaborn\27th - Project\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.dtypes
# Out:
# Film              category
# Genre               object
# CriticRating         int64
# AudienceRating       int64
# BudgetMillions       int64
# Year                 int64
# dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j =sns.jointplot(data = movies,x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
sns.distplot(movies.AudienceRating)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(movies.AudienceRating)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.distplot(movies.AudienceRating,bins=15)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.distplot(movies.AudienceRating,bins=20)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.set_style('white')
plt.hist(movies.AudienceRating,bins= 20)
# Out:
# (array([ 2.,  0.,  0.,  1.,  2., 12., 18., 35., 40., 41., 61., 63., 52.,
#         53., 33., 54., 34., 30., 23.,  5.]),
#  array([ 0. ,  4.8,  9.6, 14.4, 19.2, 24. , 28.8, 33.6, 38.4, 43.2, 48. ,
#         52.8, 57.6, 62.4, 67.2, 72. , 76.8, 81.6, 86.4, 91.2, 96. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(movies.CriticRating)
# Out:
# (array([38., 64., 75., 53., 68., 64., 43., 54., 57., 43.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies.CriticRating, bins=30) #uniform distribution
# Out:
# (array([ 9., 10., 19., 13., 35., 16., 24., 17., 34., 12., 19., 22., 29.,
#         18., 21., 17., 25., 22., 12., 16., 15., 22., 17., 15., 21., 21.,
#         15., 14., 16., 13.]),
#  array([ 0.        ,  3.23333333,  6.46666667,  9.7       , 12.93333333,
#         16.16666667, 19.4       , 22.63333333, 25.86666667, 29.1       ,
#         32.33333333, 35.56666667, 38.8       , 42.03333333, 45.26666667,
#         48.5       , 51.73333333, 54.96666667, 58.2       , 61.43333333,
#         64.66666667, 67.9       , 71.13333333, 74.36666667, 77.6       ,
#         80.83333333, 84.06666667, 87.3       , 90.53333333, 93.76666667,
#         97.        ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(movies.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Genre.value_counts()
# Out:
# Genre
# Comedy       172
# Action       154
# Drama        101
# Horror        49
# Thriller      36
# Adventure     29
# Romance       18
# Name: count, dtype: int64

# %%
plt.hist(movies.Genre)
# Out:
# (array([172.,  29.,   0., 154.,   0.,  49., 101.,   0.,  18.,  36.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions)
# Out:
# (array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=20)
# Out:
# (array([2., 9., 3., 6., 1., 1., 3., 2., 1., 1., 3., 1., 0., 1., 0., 0., 1.,
#         0., 0., 1.]),
#  array([  4.  ,  13.05,  22.1 ,  31.15,  40.2 ,  49.25,  58.3 ,  67.35,
#          76.4 ,  85.45,  94.5 , 103.55, 112.6 , 121.65, 130.7 , 139.75,
#         148.8 , 157.85, 166.9 , 175.95, 185.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=20,label='Action')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=20,label='Thriller')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=20,label='Drama')
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, 
          movies[movies.Genre == 'Drama'].BudgetMillions ,
          movies[movies.Genre == 'Thriller'].BudgetMillions,
            movies[movies.Genre == 'Comedy'].BudgetMillions], bins= 20, stacked=True)
# Out:
# (array([[  7.,  22.,  27.,  16.,   8.,  16.,   9.,   5.,   7.,   6.,  12.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 32.,  62.,  45.,  24.,  14.,  18.,  10.,   5.,   7.,   6.,  13.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 34.,  73.,  52.,  26.,  18.,  20.,  14.,   6.,   8.,   6.,  14.,
#            2.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 64., 127.,  88.,  44.,  32.,  34.,  18.,   7.,   8.,   6.,  14.,
#            3.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.]]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#         165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]),
#  <a list of 4 BarContainer objects>)

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for gen in movies.Genre.cat.categories :
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',
           fit_reg=False)

# %%
sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg=False,hue='Genre',aspect=1)

# %%
sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre', height = 10,aspect=1)

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating)

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade= True,shade_lowest=True,cmap='Reds')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade= False,shade_lowest=False,cmap='Greens_r')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.set_style('dark')
sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=True,cmap='Greens_r')
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>

# %%
sns.set_style('dark')
sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=False,cmap='Greens_r')
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>

# %%
sns.set_style('dark')
sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating)
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>

# %%
sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating)
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>

# %%
f, ax= plt.subplots(1,2,figsize=(12,6))

# %%
f,ax = plt.subplots(1,2,figsize=(12,6))
sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax= ax[0])
sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=ax[1])
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>

# %%
ax
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
sns.boxplot(data=movies,x= 'Genre',y='CriticRating')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
sns.violinplot(data=movies,x='Genre',y='CriticRating')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
sns.boxplot(data=movies[movies.Genre == 'Drama'] , x= 'Year',y = 'CriticRating')
# Out:
# <Axes: xlabel='Year', ylabel='CriticRating'>

# %%
sns.violinplot(data = movies[movies.Genre == 'Drama'],x = 'Year',y='CriticRating')
# Out:
# <Axes: xlabel='Year', ylabel='CriticRating'>

# %%
sns.FacetGrid (movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
sns.set_style('dark')
g = sns.FacetGrid(movies, row='Genre',col= 'Year',hue='Genre')
g.map(plt.scatter, 'CriticRating','AudienceRating')

# %%
g= sns.FacetGrid(movies, row= 'Genre',col='Year',hue='Genre')
g.map(plt.hist,'BudgetMillions')

# %%
sns.set_style('white')
g= sns.FacetGrid(movies, row='Genre',col= 'Year',hue= 'Genre')
kws= dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize=(15,15))

k1 = sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[0,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
z= sns.violinplot(data=movies[movies.Genre == 'Drama'],x= 'Year',y='CriticRating',ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f ,axes=plt.subplots(2,2,figsize=(15,15))
k = sns.kdeplot(x= movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=True,cmap='inferno',shade=True, ax= axes[0,0])
k1= sns.kdeplot(x=movies.BudgetMillions,y=movies.AudienceRating,cmap= 'cool',ax=axes[0,0])
k2 = sns.kdeplot(x= movies.BudgetMillions , y= movies.CriticRating,sahade=True,shade_lower=True,cmap='inferno',ax=axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillions,y=movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

sns.violinplot(data=movies[movies.Genre =='Drama'], x='Year',y='CriticRating',ax=axes[1,0])

k4 = sns.kdeplot(x= movies.CriticRating,y=movies.AudienceRating,shade=True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])
k4b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])
